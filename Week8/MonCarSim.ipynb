# %% [markdown]
# Random Numbers & Monty Carlo Simulations
# =

# %%
import numpy.random
numpy.random?

# %%
print numpy.random.random(5)
print numpy.random.random(5)
# Out:
# [ 0.55604007  0.97428455  0.69047694  0.67437146  0.21964561]
# [ 0.88827275  0.51919838  0.57587528  0.19216025  0.16008448]

# %%
#now lets use a seed to generate numbers
numpy.random.seed(4242)

print numpy.random.random(5)
# Out:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#now with no seed
numpy.random.seed(None)

print numpy.random.random(5)
# Out:
# [ 0.41969697  0.19927346  0.3245186   0.02641137  0.28957178]

# %%
#now lets try the seed again and see if its the same
numpy.random.seed(4242)
print numpy.random.random(5)
# Out:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %% [markdown]
# Example 1
# -

# %%
x = arange(0.,pi+0.001,0.01)
f = lambda x: sin(x)/2.
F = lambda x: (cos(0)-cos(x))/2.

plot(x,f(x),label='True Distribution',lw=3)
plot(x,F(x),label='Cumulitive Function',lw=3)

xlim = (0.,3.5)
ylim = (0.,1.1)

legend(loc=0)
show()

# %%
#number samples
N = 10000

#N random numbers betweem 1 and 0
z = numpy.random.random_sample(N)

#inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)
    
#sampled x values
xsamples = Finv(z)

#how do they compare to the original?
hist(xsamples,50,normed=True,label='Sampled Distribution')
plot(x,f(x),label='True distribution',lw=3,color='red')

xlim(0,pi)
ylim(0,0.7)

legend(loc=0)
show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-855501e84400> in <module>()
#      15 plot(x,f(x),label='True distribution',lw=3,color='red')
#      16
# ---> 17 xlim(0,pi)
#      18 ylim(0,0.7)
#      19
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# Ex. 1
# -

# %% [markdown]
# $f(x) = \lambda e^{-\lambda x}$

# %%
L = 1
x = arange(0.,5.,.01)
f = lambda x:L * e**(-L*x)
F = lambda x:1 + (-L * e**(-L*x))
plot(x,f(x),label='Real',lw=3,color='red')
plot(x,F(x),label='CDF',lw=3)

show()

# %%
N = 10000
z = numpy.random.random_sample(N)
Finv = lambda z:

# %% [markdown]
# Ex. 2
# -
