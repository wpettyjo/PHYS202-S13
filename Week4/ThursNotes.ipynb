# %%
from Electrostatics import *

# %%
x,y = meshgrid(arange(-3.,3.,.05),arange(-3.,3.,.05))
Vxy = pointpotential(x,y,-2e-9,-.005,0)
Gxy = dipoleppotential(x,y,3e-9,.01)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')

j = ax.plot_surface(x,y,Gxy,rstride=1,cstride=1,linewidth=0,cmap=cm.copper)

# %% [markdown]
# Using masks to find data
# =

# %%
import math

# %%
theta = arange(0.,2*pi,pi/100)
plot (theta,sin(theta))
show()

# %%
mask = (sin(theta)>0) & (sin(theta)<0.5)
print mask
plot(theta,sin(theta),theta[mask],sin(theta[mask]))
# Out:
# [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False]
# [<matplotlib.lines.Line2D at 0x10d7a07d0>,
#  <matplotlib.lines.Line2D at 0x10d7a08d0>]

# %%
y = sin(theta[mask]) 
jj = (y == max(y))
y[jj] = NaN

# %%
plot(theta,sin(theta))
plot(theta[mask],y,linewidth=4)
show()

# %% [markdown]
# interpolation
# -

# %%
theta = arange(0.,2.*pi+.1,pi/10)
mask = (theta == 0.5)

# %%
newtheta = .5; newsin = 0.
from scipy.interpolate import interp1d
#help interp1d
sinInterp = interp1d(theta,sin(theta))
newsin = sinInterp(newtheta)

# %%
print newsin
# Out:
# 0.473922198704

# %%
plot(theta,sin(theta),newtheta,newsin, 'r+',markersize = 20,markeredgewidth = 3)
show()

# %%
thetanew = arange(0.,2*pi,pi/30)
sinnew = interp1d(theta,sin(theta))(thetanew)
plot(theta,sin(theta),thetanew,sinnew, 'r*')
show()

# %%
plot(thetanew,sinnew - sin(thetanew))
ylabel('difference between intep and exact value')
show()

# %%
sinnewc = interp1d(theta,sin(theta),kind='cubic')(thetanew)
subplot(2,1,1)
plot(thetanew, sinnewc - sin(thetanew),thetanew,sinnew - sin(thetanew))
# Out:
# [<matplotlib.lines.Line2D at 0x10c78b290>,
#  <matplotlib.lines.Line2D at 0x10ce7aa50>]
